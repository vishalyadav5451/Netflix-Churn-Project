# %%
import pandas as pd

# %%
df =  pd.read_csv('netflix_customer_churn.csv')
df.head()
# Out:
#                             customer_id  age  gender subscription_type  \
# 0  a9b75100-82a8-427a-a208-72f24052884a   51   Other             Basic
# 1  49a5dfd9-7e69-4022-a6ad-0a1b9767fb5b   47   Other          Standard
# 2  4d71f6ce-fca9-4ff7-8afa-197ac24de14b   27  Female          Standard
# 3  d3c72c38-631b-4f9e-8a0e-de103cad1a7d   53   Other           Premium
# 4  4e265c34-103a-4dbb-9553-76c9aa47e946   56   Other          Standard
#
#    watch_hours  last_login_days   region  device  monthly_fee  churned  \
# 0        14.73               29   Africa      TV         8.99        1
# 1         0.70               19   Europe  Mobile        13.99        1
# 2        16.32               10     Asia      TV        13.99        0
# 3         4.51               12  Oceania      TV        17.99        1
# 4         1.89               13   Africa  Mobile        13.99        1
#
#   payment_method  number_of_profiles  avg_watch_time_per_day favorite_genre
# 0      Gift Card                   1                    0.49         Action
# 1      Gift Card                   5                    0.03         Sci-Fi
# 2         Crypto                   2                    1.48          Drama
# 3         Crypto                   2                    0.35         Horror
# 4         Crypto                   2                    0.13         Action

# %%
churn_profile = df[df['churned'] == 1].mean(numeric_only=True)
print(churn_profile)
# Out:
# age                       43.793241
# watch_hours                5.918497
# last_login_days           38.309344
# monthly_fee               13.125189
# churned                    1.000000
# number_of_profiles         2.801193
# avg_watch_time_per_day     0.164048
# dtype: float64

# %%
df.groupby('churned').mean(numeric_only=True)
# Out:
#                age  watch_hours  last_login_days  monthly_fee  \
# churned
# 0        43.902213    17.449590        21.771026    14.248350
# 1        43.793241     5.918497        38.309344    13.125189
#
#          number_of_profiles  avg_watch_time_per_day
# churned
# 0                  3.250302                1.594133
# 1                  2.801193                0.164048

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'subscription_type', 'watch_hours',
#        'last_login_days', 'region', 'device', 'monthly_fee', 'churned',
#        'payment_method', 'number_of_profiles', 'avg_watch_time_per_day',
#        'favorite_genre'],
#       dtype='object')

# %%
#1 → Customer churned (cancelled)
#0 → Customer active

# %% [markdown]
# read and understands columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             5000 non-null   object
#  1   age                     5000 non-null   int64
#  2   gender                  5000 non-null   object
#  3   subscription_type       5000 non-null   object
#  4   watch_hours             5000 non-null   float64
#  5   last_login_days         5000 non-null   int64
#  6   region                  5000 non-null   object
#  7   device                  5000 non-null   object
#  8   monthly_fee             5000 non-null   float64
#  9   churned                 5000 non-null   int64
#  10  payment_method          5000 non-null   object
#  11  number_of_profiles      5000 non-null   int64
#  12  avg_watch_time_per_day  5000 non-null   float64
#  13  favorite_genre          5000 non-null   object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 547.0+ KB

# %%
df.drop('customer_id', axis=1 , inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'gender', 'subscription_type', 'watch_hours', 'last_login_days',
#        'region', 'device', 'monthly_fee', 'churned', 'payment_method',
#        'number_of_profiles', 'avg_watch_time_per_day', 'favorite_genre'],
#       dtype='object')

# %%
df.describe()
# Out:
#                age  watch_hours  last_login_days  monthly_fee      churned  \
# count  5000.000000  5000.000000      5000.000000  5000.000000  5000.000000
# mean     43.847400    11.649450        30.089800    13.683400     0.503000
# std      15.501128    12.014654        17.536078     3.692062     0.500041
# min      18.000000     0.010000         0.000000     8.990000     0.000000
# 25%      30.000000     3.337500        15.000000     8.990000     0.000000
# 50%      44.000000     8.000000        30.000000    13.990000     1.000000
# 75%      58.000000    16.030000        45.000000    17.990000     1.000000
# max      70.000000   110.400000        60.000000    17.990000     1.000000
#
#        number_of_profiles  avg_watch_time_per_day
# count         5000.000000             5000.000000
# mean             3.024400                0.874800
# std              1.415841                2.619824
# min              1.000000                0.000000
# 25%              2.000000                0.110000
# 50%              3.000000                0.290000
# 75%              4.000000                0.720000
# max              5.000000               98.420000

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# churned                   0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %%
top_10 = df['watch_hours'].nlargest(10)  
top_10
# Out:
# 3987    110.40
# 4544    101.06
# 2017     98.42
# 339      92.07
# 3656     89.83
# 405      86.73
# 3285     83.55
# 3036     82.63
# 3391     82.61
# 1101     81.07
# Name: watch_hours, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5000 non-null   int64
#  1   gender                  5000 non-null   object
#  2   subscription_type       5000 non-null   object
#  3   watch_hours             5000 non-null   float64
#  4   last_login_days         5000 non-null   int64
#  5   region                  5000 non-null   object
#  6   device                  5000 non-null   object
#  7   monthly_fee             5000 non-null   float64
#  8   churned                 5000 non-null   int64
#  9   payment_method          5000 non-null   object
#  10  number_of_profiles      5000 non-null   int64
#  11  avg_watch_time_per_day  5000 non-null   float64
#  12  favorite_genre          5000 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 507.9+ KB

# %% [markdown]
# here we put all Numerical columns in a list

# %%
num_cols =  [
    'age' , 'watch_hours' , 'monthly_fee' , 'number_of_profiles' , 'avg_watch_time_per_day'
]

# %% [markdown]
# Mean (average) outliers se affect hota hai
#
# Median realistic value deta hai

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].median())

# %%
cat_cols = [
    'gender', 'subscription_type', 'region',
    'device', 'payment_method', 'favorite_genre'
]

# %%
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode())

# %%
df.dtypes
# Out:
# age                         int64
# gender                     object
# subscription_type          object
# watch_hours               float64
# last_login_days             int64
# region                     object
# device                     object
# monthly_fee               float64
# churned                     int64
# payment_method             object
# number_of_profiles          int64
# avg_watch_time_per_day    float64
# favorite_genre             object
# dtype: object

# %% [markdown]
# Target variable ML ke liye numeric

# %% [markdown]
# 0 = Not churned
#
# 1 = Churned

# %%
df['churned'] = df['churned'].astype(int)

# %%
# #remove invaild values 
df = df[df['watch_hours'] >= 0]
df = df[df['monthly_fee']>0]

# %% [markdown]
# Basic → 0
# Standard → 1
# Premium → 2
#
# female -> 0
# male -> 1
# other -> 2

# %% [markdown]
# ML models not understand text
# Simple and  fast
# sufficient for Churn prediction
#
# good work with Decision Tree / Random Forest

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoders = {}

for col in cat_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    encoders[col] = le

# %%
encoders['favorite_genre'].classes_
# Out:
# array(['Action', 'Comedy', 'Documentary', 'Drama', 'Horror', 'Romance',
#        'Sci-Fi'], dtype=object)

# %%
print(encoders.keys())
# Out:
# dict_keys(['gender', 'subscription_type', 'region', 'device', 'payment_method', 'favorite_genre'])

# %%
df.head()
# Out:
#    age  gender  subscription_type  watch_hours  last_login_days  region  \
# 0   51       2                  0        14.73               29       0
# 1   47       2                  2         0.70               19       2
# 2   27       0                  2        16.32               10       1
# 3   53       2                  1         4.51               12       4
# 4   56       2                  2         1.89               13       0
#
#    device  monthly_fee  churned  payment_method  number_of_profiles  \
# 0       3         8.99        1               3                   1
# 1       2        13.99        1               3                   5
# 2       3        13.99        0               1                   2
# 3       3        17.99        1               1                   2
# 4       2        13.99        1               1                   2
#
#    avg_watch_time_per_day  favorite_genre
# 0                    0.49               0
# 1                    0.03               6
# 2                    1.48               3
# 3                    0.35               4
# 4                    0.13               0

# %% [markdown]
# StandardScaler
#
# Model should not give too much importance to any one feature
# for Fair learning
# it must for Logistic Regression models

# %%
# from sklearn.preprocessing import StandardScaler

# scaler = StandardScaler()
# df[num_cols] = scaler.fit_transform(df[num_cols])

# %%
df
# Out:
#       age  gender  subscription_type  watch_hours  last_login_days  region  \
# 0      51       2                  0        14.73               29       0
# 1      47       2                  2         0.70               19       2
# 2      27       0                  2        16.32               10       1
# 3      53       2                  1         4.51               12       4
# 4      56       2                  2         1.89               13       0
# ...   ...     ...                ...          ...              ...     ...
# 4995   19       0                  0        49.17               11       2
# 4996   67       0                  0         9.24                2       3
# 4997   66       1                  2        16.55               49       5
# 4998   59       0                  0         9.12                3       2
# 4999   57       1                  0         1.62               17       0
#
#       device  monthly_fee  churned  payment_method  number_of_profiles  \
# 0          3         8.99        1               3                   1
# 1          2        13.99        1               3                   5
# 2          3        13.99        0               1                   2
# 3          3        17.99        1               1                   2
# 4          2        13.99        1               1                   2
# ...      ...          ...      ...             ...                 ...
# 4995       0         8.99        0               0                   4
# 4996       0         8.99        0               4                   3
# 4997       0        13.99        1               2                   2
# 4998       1         8.99        0               0                   4
# 4999       2         8.99        1               1                   2
#
#       avg_watch_time_per_day  favorite_genre
# 0                       0.49               0
# 1                       0.03               6
# 2                       1.48               3
# 3                       0.35               4
# 4                       0.13               0
# ...                      ...             ...
# 4995                    4.10               3
# 4996                    3.08               2
# 4997                    0.33               0
# 4998                    2.28               6
# 4999                    0.09               0
#
# [5000 rows x 13 columns]

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5000 non-null   int64
#  1   gender                  5000 non-null   int64
#  2   subscription_type       5000 non-null   int64
#  3   watch_hours             5000 non-null   float64
#  4   last_login_days         5000 non-null   int64
#  5   region                  5000 non-null   int64
#  6   device                  5000 non-null   int64
#  7   monthly_fee             5000 non-null   float64
#  8   churned                 5000 non-null   int64
#  9   payment_method          5000 non-null   int64
#  10  number_of_profiles      5000 non-null   int64
#  11  avg_watch_time_per_day  5000 non-null   float64
#  12  favorite_genre          5000 non-null   int64
# dtypes: float64(3), int64(10)
# memory usage: 507.9 KB
# age                       0
# gender                    0
# subscription_type         0
# watch_hours               0
# last_login_days           0
# region                    0
# device                    0
# monthly_fee               0
# churned                   0
# payment_method            0
# number_of_profiles        0
# avg_watch_time_per_day    0
# favorite_genre            0
# dtype: int64

# %%
df.to_csv("cleaned_netflix_data.csv", index=False)

# %% [markdown]
# Exploratory Data Analysis (EDA)
# Observation the Data ,
# Business Meaning
#
#
# Customer behavior samajhte hain
# Churn ke main reasons identify karte hain
# Decide karte hain kaunse features ML me important honge

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('cleaned_netflix_data.csv')

print("Dataset Loaded Successfully")
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print(df.info())
# Out:
# Dataset Loaded Successfully
# Rows: 5000
# Columns: 13
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     5000 non-null   int64
#  1   gender                  5000 non-null   int64
#  2   subscription_type       5000 non-null   int64
#  3   watch_hours             5000 non-null   float64
#  4   last_login_days         5000 non-null   int64
#  5   region                  5000 non-null   int64
#  6   device                  5000 non-null   int64
#  7   monthly_fee             5000 non-null   float64
#  8   churned                 5000 non-null   int64
#  9   payment_method          5000 non-null   int64
#  10  number_of_profiles      5000 non-null   int64
#  11  avg_watch_time_per_day  5000 non-null   float64
#  12  favorite_genre          5000 non-null   int64
# dtypes: float64(3), int64(10)
# memory usage: 507.9 KB
# None

# %% [markdown]
# check customers churn and  customers active

# %%
counts = df['churned'].value_counts()
counts
# Out:
# churned
# 1    2515
# 0    2485
# Name: count, dtype: int64

# %% [markdown]
# for understand data here we use (countplot for categorical data) and (boxplot for numerical data)

# %%
sns.countplot(x='churned' , data=df)
plt.title("Churn Distribution")
plt.show()


# The target variable analysis shows class imbalance which  common in real world churn data

# %% [markdown]
# Watch Hours vs Churn

# %%
sns.boxplot(x='churned', y='watch_hours', data=df)
plt.title("Watch Hours vs Churn")
plt.show()


# #Netflix ko low-engagement users ko re-engage karna chahiye.

# %% [markdown]
# Subscription Type vs Churn

# %% [markdown]
# which plan choose most

# %%
sns.countplot(x='subscription_type', hue='churned', data=df)
plt.title("Subscription Type vs Churn")
plt.show()

# %% [markdown]
# Last Login Days vs Churn

# %% [markdown]
# Inactive users churned

# %%
sns.boxplot(x='churned', y='last_login_days', data=df)
plt.title("Last Login Days vs Churn")
plt.show()



# #Early reminders or notifications reduce the churn

# %% [markdown]
# Monthly Fee vs Churn

# %%
sns.boxplot(x= 'churned', y='monthly_fee' , data=df)
plt.title('Monthly Fee Vs Churned')
plt.show()


# #Here not big effect monthly fee on churned

# %% [markdown]
# Device vs Churn
#
# is device effect on churn

# %%
sns.countplot(hue='churned', x='device' ,  data=df)
plt.title("Device vs Churn")
plt.show()

# %% [markdown]
# Correlation Heatmap
#
# whice numerical features are strongly related to churn
#
#
# For Feature selection
# which variables are highly correlated with each other

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# Feature Engineering

# %%
df.head()
# Out:
#    age  gender  subscription_type  watch_hours  last_login_days  region  \
# 0   51       2                  0        14.73               29       0
# 1   47       2                  2         0.70               19       2
# 2   27       0                  2        16.32               10       1
# 3   53       2                  1         4.51               12       4
# 4   56       2                  2         1.89               13       0
#
#    device  monthly_fee  churned  payment_method  number_of_profiles  \
# 0       3         8.99        1               3                   1
# 1       2        13.99        1               3                   5
# 2       3        13.99        0               1                   2
# 3       3        17.99        1               1                   2
# 4       2        13.99        1               1                   2
#
#    avg_watch_time_per_day  favorite_genre
# 0                    0.49               0
# 1                    0.03               6
# 2                    1.48               3
# 3                    0.35               4
# 4                    0.13               0

# %%
#show User interest level

df['engagement_score'] = (df['avg_watch_time_per_day'] * df['watch_hours'])

# %%
df['engagement_score']
# Out:
# 0         7.2177
# 1         0.0210
# 2        24.1536
# 3         1.5785
# 4         0.2457
#           ...
# 4995    201.5970
# 4996     28.4592
# 4997      5.4615
# 4998     20.7936
# 4999      0.1458
# Name: engagement_score, Length: 5000, dtype: float64

# %% [markdown]
# inactive_flag identifies inactive users, which strongly helps predict churn.

# %%
df['inactive_flag'] = df['last_login_days'].apply(lambda x : 1 if x > 30 else 0)

# %%
df['high_price_flag'] = df['monthly_fee'].apply(
    lambda x: 1 if x > df['monthly_fee'].median() else 0
)

# %%
df.drop(['avg_watch_time_per_day'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 5000 non-null   int64
#  1   gender              5000 non-null   int64
#  2   subscription_type   5000 non-null   int64
#  3   watch_hours         5000 non-null   float64
#  4   last_login_days     5000 non-null   int64
#  5   region              5000 non-null   int64
#  6   device              5000 non-null   int64
#  7   monthly_fee         5000 non-null   float64
#  8   churned             5000 non-null   int64
#  9   payment_method      5000 non-null   int64
#  10  number_of_profiles  5000 non-null   int64
#  11  favorite_genre      5000 non-null   int64
#  12  engagement_score    5000 non-null   float64
#  13  inactive_flag       5000 non-null   int64
#  14  high_price_flag     5000 non-null   int64
# dtypes: float64(3), int64(12)
# memory usage: 586.1 KB

# %% [markdown]
# Features (X) & Target (y)

# %%
x = df.drop('churned' , axis =1)
y = df['churned']

# %%
from sklearn.model_selection import  train_test_split
x_train , x_test ,y_train , y_test = train_test_split(x ,y , test_size=0.2 , random_state=42 , stratify=y)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', RandomForestClassifier())
])

pipeline.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('model', RandomForestClassifier())])

# %%
from sklearn import set_config
set_config(display='diagram')

# %%
x_train.shape ,x_test.shape
# Out:
# ((4000, 14), (1000, 14))

# %%
y_train.shape
# Out:
# (4000,)

# %%
x_test[y_test == 1].iloc[:5]
# Out:
#       age  gender  subscription_type  watch_hours  last_login_days  region  \
# 3551   67       0                  1         2.34               54       5
# 3182   31       0                  0         9.44               46       1
# 3678   59       0                  1         0.10               20       3
# 1873   52       0                  0         1.59               29       5
# 2831   30       0                  2         6.23               49       2
#
#       device  monthly_fee  payment_method  number_of_profiles  favorite_genre  \
# 3551       2        17.99               0                   4               2
# 3182       4         8.99               4                   2               0
# 3678       1        17.99               1                   1               6
# 1873       3         8.99               4                   3               0
# 2831       3        13.99               2                   3               1
#
#       engagement_score  inactive_flag  high_price_flag
# 3551            0.0936              1                1
# 3182            1.8880              1                0
# 3678            0.0000              0                1
# 1873            0.0795              0                0
# 2831            0.7476              1                0

# %%
cols =  [
    'age' , 'watch_hours' , 'monthly_fee' , 'number_of_profiles'  ,'engagement_score' ,'inactive_flag','payment_method','churned'
]

# %%
sns.stripplot(data=df, x='churned', y='watch_hours', hue='churned', jitter=True)
plt.show()

# %%
y_train.value_counts(normalize=True)
# Out:
# churned
# 1    0.503
# 0    0.497
# Name: proportion, dtype: float64

# %% [markdown]
# ML Model Training”

# %% [markdown]
# Logistic Regression
# Decision Tree
# Random Forest

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
print(y_train.head())
print(y_train.unique())
print(y_train.dtype)
# Out:
# 1310    0
# 2139    1
# 3293    1
# 134     1
# 2619    0
# Name: churned, dtype: int64
# [0 1]
# int64

# %%
# rf_model = RandomForestClassifier(n_estimators=500)
# rf_model.fit(x_train , y_train)

# %%
rf_pred = pipeline.predict(x_test)
accuracy_score(y_test,rf_pred)
# Out:
# 0.965

# %%
ref_prob = pipeline.predict_proba(x_test)[:,1]

# %%
from sklearn.metrics import precision_recall_curve
precision,recall,threshold = precision_recall_curve(y_test , ref_prob)

plt.figure(figsize=(6,5))
plt.plot(recall, precision)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.show()

# %%
from sklearn.metrics import accuracy_score , precision_score , recall_score , f1_score , confusion_matrix , classification_report

# %%
confusion_matrix(y_test , rf_pred)
# Out:
# array([[487,  10],
#        [ 25, 478]])

# %% [markdown]
# Classification Report

# %%
print('RandomForest')
print(classification_report(y_test , rf_pred))
# Out:
# RandomForest
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       497
#            1       0.98      0.95      0.96       503
#
#     accuracy                           0.96      1000
#    macro avg       0.97      0.97      0.96      1000
# weighted avg       0.97      0.96      0.96      1000

# %%
model = pipeline.named_steps['model']

feature_importance = pd.DataFrame({
    'Feature': x.columns,
    'Importance': model.feature_importances_
}).sort_values(by='Importance', ascending=False)

print(feature_importance)
# Out:
#                Feature  Importance
# 11    engagement_score    0.312351
# 3          watch_hours    0.222171
# 4      last_login_days    0.153422
# 12       inactive_flag    0.098744
# 9   number_of_profiles    0.063976
# 8       payment_method    0.031844
# 0                  age    0.024284
# 2    subscription_type    0.020922
# 7          monthly_fee    0.020379
# 10      favorite_genre    0.014028
# 5               region    0.013440
# 6               device    0.011479
# 1               gender    0.008574
# 13     high_price_flag    0.004387

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.barplot(
    x='Importance',
    y='Feature',
    data=feature_importance.head(10)
)
plt.title("Top 10 Features Influencing Churn")
plt.show()

# %%
import joblib
joblib.dump(pipeline, "pipeline.pkl")
# Out:
# ['pipeline.pkl']

# %%
print(x.shape)
# Out:
# (5000, 14)

# %%
print(pipeline.n_features_in_)
# Out:
# 14

# %%
print(y.value_counts())
# Out:
# churned
# 1    2515
# 0    2485
# Name: count, dtype: int64

# %%
print(x.columns)
# Out:
# Index(['age', 'gender', 'subscription_type', 'watch_hours', 'last_login_days',
#        'region', 'device', 'monthly_fee', 'payment_method',
#        'number_of_profiles', 'favorite_genre', 'engagement_score',
#        'inactive_flag', 'high_price_flag'],
#       dtype='object')

# %% [markdown]
# test parpas

# %%
import numpy as np

# Same values
age = 67
gender = 0
subscription_type = 1
watch_hours = 2.34
last_login_days = 54
region = 2
device = 1
monthly_fee = 17.99
payment_method = 1
number_of_profiles = 2
avg_watch_time_per_day = 0.04
favorite_genre = 3
engagement_score = watch_hours * avg_watch_time_per_day
inactive_flag = 1 if last_login_days > 30 else 0
high_price_flag = 1 if monthly_fee > 500 else 0

X = np.array([[ 
    age,
    gender,
    subscription_type,
    watch_hours,
    last_login_days,
    region,
    device,
    monthly_fee,
    payment_method,
    number_of_profiles,
    favorite_genre,
    engagement_score,
    inactive_flag,
    high_price_flag
]])

print(pipeline.predict(X))
print(pipeline.predict_proba(X))
# Out:
# [1]
# [[0. 1.]]
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
churn_profile = df[df['churned'] == 1].mean(numeric_only=True)
print(churn_profile)
# Out:
# age                   43.793241
# gender                 0.976143
# subscription_type      0.889066
# watch_hours            5.918497
# last_login_days       38.309344
# region                 2.529622
# device                 2.035388
# monthly_fee           13.125189
# churned                1.000000
# payment_method         2.034990
# number_of_profiles     2.801193
# favorite_genre         2.974155
# engagement_score       1.531138
# inactive_flag          0.737177
# high_price_flag        0.294235
# dtype: float64

# %%
df.groupby('churned').mean(numeric_only=True)
# Out:
#                age    gender  subscription_type  watch_hours  last_login_days  \
# churned
# 0        43.902213  0.993561           1.106237    17.449590        21.771026
# 1        43.793241  0.976143           0.889066     5.918497        38.309344
#
#            region    device  monthly_fee  payment_method  number_of_profiles  \
# churned
# 0        2.491348  2.038632    14.248350        1.999598            3.250302
# 1        2.529622  2.035388    13.125189        2.034990            2.801193
#
#          favorite_genre  engagement_score  inactive_flag  high_price_flag
# churned
# 0              3.079678         41.100894       0.247485         0.383501
# 1              2.974155          1.531138       0.737177         0.294235

# %%
import numpy as np

X = np.array([[ 
    67, 0, 1, 2.34, 54, 2, 1, 17.99, 1, 2, 3, 
    5*0.04, 1, 1
]])

print(pipeline.predict(X))
print(pipeline.predict_proba(X))
# Out:
# [1]
# [[0. 1.]]
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
probs = pipeline.predict_proba(X)[:,1]

print("Min:", probs.min())
print("Max:", probs.max())
# Out:
# Min: 1.0
# Max: 1.0
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
pipeline.predict_proba(X)
# Out:
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0., 1.]])

# %%
probs = pipeline.predict_proba(x_test)[:,1]
print(probs[:10])
# Out:
# [0.   0.96 0.33 1.   0.9  0.99 0.96 1.   0.45 0.45]

# %%
y_prob = pipeline.predict_proba(x_test)[0][1]

if y_prob > 0.3:
    print("Churn")
else:
    print("Not Churn")
# Out:
# Not Churn

# %%
input_data = [1.5,   # age (scaled ~ above avg)
              0,     # gender
              1,     # subscription_type
              -1.2,  # watch_hours (VERY LOW ⚠️)
              60,    # last_login_days (VERY HIGH ⚠️)
              3,     # region
              2,     # device
              1.5,   # monthly_fee (HIGH ⚠️)
              1,     # payment_method
              0.3,   # number_of_profiles (LOW ⚠️)
              2,     # favorite_genre
              0.1,   # engagement_score (VERY LOW ⚠️)
              1,     # inactive_flag (YES 🚨)
              1]     # high_price_flag (YES 🚨)

# %%
import numpy as np

X = np.array([input_data])

pred = pipeline.predict(X)
prob = pipeline.predict_proba(X)

print("Prediction:", pred)
print("Probability:", prob)
# Out:
# Prediction: [1]
# Probability: [[0.01 0.99]]
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# c:\Users\visha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
mapping = dict(zip(le.transform(le.classes_), le.classes_))
print(mapping)
# Out:
# {np.int64(0): 'Action', np.int64(1): 'Comedy', np.int64(2): 'Documentary', np.int64(3): 'Drama', np.int64(4): 'Horror', np.int64(5): 'Romance', np.int64(6): 'Sci-Fi'}
